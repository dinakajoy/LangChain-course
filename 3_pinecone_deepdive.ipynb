# %% [markdown]
# # Deep dive into Pinecone
#
# - Working with Pinecone indexes
# - Working with vectors
# - Namespaces

# %%
pip install -q pinecone
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show pinecone
# Out:
# Name: pinecone
# Version: 7.3.0
# Summary: Pinecone client and SDK
# Home-page: https://www.pinecone.io
# Author: Pinecone Systems, Inc.
# Author-email: support@pinecone.io
# License: Apache-2.0
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: certifi, pinecone-plugin-assistant, pinecone-plugin-interface, python-dateutil, typing-extensions, urllib3
# Required-by: langchain-pinecone
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from pinecone import Pinecone
pc = Pinecone()
pc.list_indexes()
# Out:
# []

# %% [markdown]
# ## Working with Pinecone Indexes

# %%
# Delete index
index_name = "langchain-demo"
if index_name in pc.list_indexes().names():
    print(f'Deleting index: {index_name}...')
    pc.delete_index(index_name)
    print('Index deleted!')
else:
    print(f'Index {index_name} does not exist!')
# Out:
# Index langchain-demo does not exist!

# %%
from pinecone import Pinecone, ServerlessSpec

# Create index
index_name = "langchain-demo"

if index_name not in pc.list_indexes().names():
    print(f'Creating index: {index_name}...')
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric='cosine',
        spec=ServerlessSpec(
            cloud='aws',
            region='us-east-1'
        )
    )
    print('Index created!')
else:
    print(f'Index {index_name} already exists!')
# Out:
# Creating index: langchain-demo...
# Index created!

# %%
pc.list_indexes()[0]['name']
pc.describe_index(index_name) # Where langchain-demo is the name of index from line 1
pc.list_indexes().names() # To list all names of indexes available
# Out:
# ['langchain-demo']

# %%
index = pc.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %% [markdown]
# ## Working with Vectors

# %%
# Inserting vectors

import random
vectors = [[random.random() for _ in range(1536)] for v in range(5)]
# print(vectors)
ids = list('abcde')

index = pc.Index(index_name)

index.upsert(vectors=zip(ids, vectors))
# Out:
# {'upserted_count': 5}

# %%
# Updating vectors
index.upsert(vectors=[('c', [0.5] * 1536)])
# Out:
# {'upserted_count': 1}

# %%
# Fetching vectors
index.fetch(ids=['c', 'd'])
# Out:
# FetchResponse(namespace='', vectors={'c': Vector(id='c', values=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,  ...

# %%
# Deleting vectors
index.delete(ids=['b', 'c'])
# Out:
# {}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 3}},
#  'total_vector_count': 3,
#  'vector_type': 'dense'}

# %%
# Fetch index that don't exist returns an empty vector
index.fetch(ids=['x'])
# Out:
# FetchResponse(namespace='', vectors={}, usage={'read_units': 1})

# %%
# query for similar vectors
query_vector = [random.random() for _ in range(1536)]

# %%
index.query(
    vector=query_vector,
    top_k=3,
    include_values=False
)
# Out:
# {'matches': [{'id': 'd', 'score': 0.762344837, 'values': []},
#              {'id': 'e', 'score': 0.754647434, 'values': []},
#              {'id': 'a', 'score': 0.750887036, 'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 1}}

# %% [markdown]
# ## Namespace

# %%
# Insert 5 vectors with empty namespace
vectors = [[random.random() for _ in range(1536)] for v in range(5)]
ids = list('abcde')
index.upsert(vectors=zip(ids, vectors))
# Out:
# {'upserted_count': 5}

# %%
# Insert 3 vectors with a namespace: first-namespace
vectors = [[random.random() for _ in range(1536)] for v in range(3)]
ids = list('xyz')
index.upsert(vectors=zip(ids, vectors), namespace='first-namespace')
# Out:
# {'upserted_count': 3}

# %%
# Insert 2 vectors with a namespace: second-namespace
vectors = [[random.random() for _ in range(1536)] for v in range(2)]
ids = list('gh')
index.upsert(vectors=zip(ids, vectors), namespace='second-namespace')
# Out:
# {'upserted_count': 2}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 5},
#                 'first-namespace': {'vector_count': 3}},
#  'total_vector_count': 8,
#  'vector_type': 'dense'}

# %%
# Won't find it because namespace was not specified and by default it searches the namespase of ""
index.fetch(ids=['x'])
# Out:
# FetchResponse(namespace='', vectors={}, usage={'read_units': 1})

# %%
index.fetch(ids=['x'], namespace='first-namespace')
# Out:
# FetchResponse(namespace='first-namespace', vectors={'x': Vector(id='x', values=[0.84210515, 0.793016493, 0.432615161, 0.644184351, 0.511622608, 0.0628359839, 0.318293273, 6.67085333e-05, 0.544837832, 0.812546134, 0.909740925, 0.510501325, 0.147645801, 0.0651393235, 0.87763232, 0.0578864887, 0.993318, 0.22553429, 0.551717877, 0.920382679, 0.18207401, 0.0193921048, 0.672301114, 0.761582792, 0.185816646, 0.93648994, 0.913551629, 0.483782858, 0.416026145, 0.738653183, 0.648696363, 0.463015139, 0.603665352, 0.981060803, 0.469784141, 0.514602363, 0.096319, 0.198917016, 0.741958737, 0.842866421, 0.850967646, 0.486544669, 0.73457396, 0.04225168, 0.463538557, 0.713171363, 0.828429163, 0.668151557, 0.227840081, 0.767631829, 0.0967603475, 0.802779615, 0.320016354, 0.177191854, 0.644589663, 0.654713333, 0.536572874, 0.409288645, 0.208583817, 0.648289263, 0.754021347, 0.420870751, 0.447029501, 0.661640525, 0.947170198, 0.256326258, 0.132782981, 0.0960297883, 0.124681905, 0.828774154, 0.476964444, 0.875863135, 0.923410654, 0.953157485, 0.416240692, 0.562954605, 0.619518399, 0.571739376, 0.424250633, 0.896335781, 0.974635124, 0.175117642, 0.0439644679, 0.28352192, 0.660621285, 0.317557812, 0.596554518, 0.531069875, 0.714163721, 0.925297916, 0.543037474, 0.642070889, 0.352267593, 0.26198104, 0.999348819, 0.742766142, 0.40495652, 0.946243405, 0.953834057, 0.935757, 0.968964815, 0.125591323, 0.905978858, 0.262962908, 0.407595456, 0.904191434, 0.803044319, 0.948445, 0.745203555, 0.502239466, 0.470600396, 0.297302902, 0.714048743, 0.574759841, 0.480769426, 0.495663226, 0.0638284385, 0.10131371, 0.80520463, 0.853766382, 0.035766881, 0.256024361, 0.548075318, 0.945996284, 0.780909, 0.235693529, 0.0250124447, 0.463575631, 0.646944463, 0.887367189, 0.984963477, 0.641605, 0.718602419, 0.456295252, 0.479025692, 0.880256772, 0.599580944, 0.0892994478, 0.817929804, 0.123128846, 0.0839360058, 0.786455929, 0.331668228, 0.712632358, 0.0921934471, 0.242145166, 0.0359156094, 0.925216377, 0.474638104, 0.60458982, 0.0539407544, 0.151068151, 0.530438721, 0.203679234, 0.903787673, 0.868013, 0.643521547, 0.259356767, 0.325978607, 0.646605551, 0.947205067, 0.81977129, 0.284357488, 0.0439188182, 0.7873469, 0.840815485, 0.873292565, 0.472694904, 0.760946095, 0.653285921, 0.174257562, 0.823557794, 0.473663479, 0.449224, 0.621540427, 0.426339835, 0.608143926, 0.706534684, 0.270688236, 0.444954306, 0.304596603, 0.0270809811, 0.932510793, 0.0858770683, 0.713328183, 0.696258307, 0.584322274, 0.0154538732, 0.719816148, 0.86684972, 0.107796863, 0.89431715, 0.0669770539, 0.916256666, 0.973918915, 0.541313589, 0.430385888, 0.56695658, 0.0266073663, 0.0449507758, 0.497704148, 0.897839963, 0.442390174, 0.262933075, 0.0133549822, 0.888437867, 0.854331791, 0.724094152, 0.264238298, 0.410081804, 0.956487358, 0.14568904, 0.813333809, 0.150623634, 0.146062911, 0.819265723, 0.952945888, 0.852149308, 0.023471633, 0.563015223, 0.548997283, 0.0215053502, 0.834007621, 0.135935813, 0.536613, 0.995082915, 0.800622642, 0.117877662, 0.0810059234, 0.0225855485, 0.248130515, 0.132912472, 0.201781884, 0.662458897, 0.767826319, 0.246837094, 0.741753936, 0.48401767, 0.792767346, 0.275116056, 0.564162731, 0.0047736587, 0.788059771, 0.246087134, 0.83213824, 0.968646407, 0.0554612204, 0.79231894, 0.911151588, 0.828621209, 0.963239193, 0.192006469, 0.709824622, 0.644938588, 0.29046455, 0.817545652, 0.844427347, 0.728746593, 0.150369272, 0.637988031, 0.825484693, 0.127890274, 0.678964794, 0.0394680761, 0.344737202, 0.152148977, 0.175054714, 0.464082569, 0.697827756, 0.0194303971, 0.605631232, 0.00538714975, 0.545393825, 0.724114895, 0.0948285758, 0.192330107, 0.239246592, 0.0331873894, 0.881144047, 0.118802071, 0.570938885, 0.7686854, 0.906903386, 0.0903256685, 0.155301839, 0.604901075, 0.97270906, 0.0147453416, 0.0737685114, 0.263295114, 0.138173252, 0.739622295, 0.160621077, 0.809372723, 0.639678776, 0.174167395, 0.936587334, 0.72950834, 0.891626, 0.409334958, 0.144457728, 0.788231432, 0.472472, 0.8 ...

# %%
# Same with deleting
index.delete(ids=['x'], namespace='first-namespace')
# Out:
# {}

# %%
# To delete all from a namespace (also deletes the namespace itself)
index.delete(delete_all=True)
index.delete(delete_all=True, namespace='first-namespace')
index.delete(delete_all=True, namespace='second-namespace')
# Out:
# {}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}
